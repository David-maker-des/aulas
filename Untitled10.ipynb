# %%
x = 0
while x <= 100000:
    print('valor do x')
    print(x)
    x=x+100
else:
    print('the end')
# Out:
# valor do x
# 0
# valor do x
# 100
# valor do x
# 200
# valor do x
# 300
# valor do x
# 400
# valor do x
# 500
# valor do x
# 600
# valor do x
# 700
# valor do x
# 800
# valor do x
# 900
# valor do x
# 1000
# valor do x
# 1100
# valor do x
# 1200
# valor do x
# 1300
# valor do x
# 1400
# valor do x
# 1500
# valor do x
# 1600
# valor do x
# 1700
# valor do x
# 1800
# valor do x
# 1900
# valor do x
# 2000
# valor do x
# 2100
# valor do x
# 2200
# valor do x
# 2300
# valor do x
# 2400
# valor do x
# 2500
# valor do x
# 2600
# valor do x
# 2700
# valor do x
# 2800
# valor do x
# 2900
# valor do x
# 3000
# valor do x
# 3100
# valor do x
# 3200
# valor do x
# 3300
# valor do x
# 3400
# valor do x
# 3500
# valor do x
# 3600
# valor do x
# 3700
# valor do x
# 3800
# valor do x
# 3900
# valor do x
# 4000
# valor do x
# 4100
# valor do x
# 4200
# valor do x
# 4300
# valor do x
# 4400
# valor do x
# 4500
# valor do x
# 4600
# valor do x
# 4700
# valor do x
# 4800
# valor do x
# 4900
# ...

# %%
x = int(input('qual numero?')
while x <= 100:
    print(x)
    x = x*1
else:
    print('the end')
# Out:
#   Cell In[12], line 1
#     x = int(input('qual numero?')
#            ^
# SyntaxError: '(' was never closed
